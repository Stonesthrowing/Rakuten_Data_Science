# %%
# !uv pip install nltk
# Out:
# Using Python 3.14.0 environment at: C:\Users\Ion\.venv
# Resolved 6 packages in 762ms
# Downloading nltk (1.5MiB)
#  Downloaded nltk
# Prepared 5 packages in 1.24s
# Installed 5 packages in 906ms
#  + click==8.3.1
#  + joblib==1.5.3
#  + nltk==3.9.3
#  + regex==2026.2.28
#  + tqdm==4.67.3

# %%
import os
os.chdir(path=r"C:\Users\Ion\Documents\working now\job\datascientist\rakuten_project")
os.getcwd()
# Out:
# 'C:\\Users\\Ion\\Documents\\working now\\job\\datascientist\\rakuten_project'

# %%
display(os.listdir())
display(os.listdir("images"))
display(os.listdir("images/image_train")[:10])
# Out:
# ['.git',
#  'images',
#  'images.zip',
#  'Rakuten.docx',
#  'Rakuten_Data_Science',
#  'X_test_update.csv',
#  'X_train_update.csv',
#  'Y_train_CVw08PX.csv']
# ['image_test', 'image_train']
# ['image_1000076039_product_580161.jpg',
#  'image_1000089455_product_348990858.jpg',
#  'image_1000092894_product_353108104.jpg',
#  'image_1000093804_product_343306951.jpg',
#  'image_1000095646_product_344209267.jpg',
#  'image_1000095647_product_148177050.jpg',
#  'image_1000099971_product_352683003.jpg',
#  'image_1000100220_product_352601770.jpg',
#  'image_1000222973_product_351172420.jpg',
#  'image_1000228891_product_355017693.jpg']

# %%
import pandas as pd

X_train = pd.read_csv("X_train_update.csv")
Y_train = pd.read_csv("Y_train_CVw08PX.csv")
X_test = pd.read_csv("X_test_update.csv")

print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_test shape:", X_test.shape)

display(X_train.head())
display(Y_train.head())

display(X_train.info())
display(X_train.describe(include="all"))
# Out:
# X_train shape: (84916, 5)
# Y_train shape: (84916, 2)
# X_test shape: (13812, 5)
#    Unnamed: 0                                        designation  \
# 0           0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1           1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2           2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3           3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4           4                               La Guerre Des Tuques
#
#                                          description   productid     imageid
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#    Unnamed: 0  prdtypecode
# 0           0           10
# 1           1         2280
# 2           2           50
# 3           3         1280
# 4           4         2705
# <class 'pandas.DataFrame'>
# RangeIndex: 84916 entries, 0 to 84915
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   84916 non-null  int64
#  1   designation  84916 non-null  str
#  2   description  55116 non-null  str
#  3   productid    84916 non-null  int64
#  4   imageid      84916 non-null  int64
# dtypes: int64(3), str(2)
# memory usage: 3.2 MB
# None
#           Unnamed: 0                                        designation  \
# count   84916.000000                                              84916
# unique           NaN                                              82265
# top              NaN  5d Broderie Peintures Strass Diamant Bricolage...
# freq             NaN                                                 76
# mean    42457.500000                                                NaN
# std     24513.282066                                                NaN
# min         0.000000                                                NaN
# 25%     21228.750000                                                NaN
# 50%     42457.500000                                                NaN
# 75%     63686.250000                                                NaN
# max     84915.000000                                                NaN
#
#                                               description     productid  \
# count                                               55116  8.491600e+04
# unique                                              47506           NaN
# top     <br>Attention !!! Ce produit est un import  si...           NaN
# freq                                                  252           NaN
# mean                                                  NaN  2.555468e+09
# std                                                   NaN  1.588656e+09
# min                                                   NaN  1.839120e+05
# 25%                                                   NaN  6.760519e+08
# 50%                                                   NaN  3.190506e+09
# 75%                                                   NaN  3.995599e+09
# max                                                   NaN  4.252012e+09
#
#              imageid
# count   8.491600e+04
# unique           NaN
# top              NaN
# freq             NaN
# mean    1.152691e+09
# std     1.751427e+08
# min     6.728400e+04
# 25%     1.056269e+09
# 50%     1.213354e+09
# 75%     1.275646e+09
# max     1.328824e+09

# %%
df = pd.merge(X_train, Y_train, on="Unnamed: 0")

print(df.shape)
df.head()
# Out:
# (84916, 6)
#    Unnamed: 0                                        designation  \
# 0           0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1           1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2           2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3           3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4           4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#    prdtypecode
# 0           10
# 1         2280
# 2           50
# 3         1280
# 4         2705

# %%
df_code = df[df['prdtypecode'] == 1180]
display(df_code.head(10))
with pd.option_context("display.max_colwidth", None):
    print(df_code.designation.head(10))

from PIL import Image
import matplotlib.pyplot as plt
import os

for _, row in df_code.head(10).iterrows():
    filename = f"image_train/image_{row['imageid']}_product_{row['productid']}.jpg"
    path = os.path.join("images", filename)   # change folder if needed
    
    img = Image.open(path)
    
    plt.imshow(img)
    plt.title(filename)
    plt.axis("off")
    plt.show()
# Out:
#      Unnamed: 0                                        designation  \
# 22           22  Le Seigneur Des Anneaux Figurine En Plomb À Pe...
# 41           41                 Présentoir À Biscuits Et Chocolats
# 106         106  Comtes Vampires Lahmiane À Pied Et Montée Lahm...
# 154         154   Mournblade - Ecran Et Cartes Des Jeunes Royaumes
# 524         524  Warhammer 40000 ( 40k ) - Exo Armure Xv88 Broa...
# 666         666                 Greyhawk Ad&d The Adventure Begins
# 721         721                             Rage Across The Amazon
# 747         747  Masque Halloween Masques Led Glow Light Up Mas...
# 764         764  Vert Intérieur P010 Gamme Air - Pot De 17ml - ...
# 999         999                        Red Steel - Savage Baronies
#
#                                            description   productid  \
# 22                                                 NaN  1893048509
# 41                                                 NaN  1548294503
# 106                                                NaN  4187799604
# 154                                                NaN  4180534759
# 524  Ce kit contient 91 composants en plastique ain...   255257554
# 666                                                NaN  3404365132
# 721                                                NaN    18063547
# 747  Masque Halloween LED Masques Glow Masque Effra...  4151009771
# 764                                                NaN   273333595
# 999  <br />Daring swashbucklers.<br />Stout mercena...    76198034
#
#         imageid  prdtypecode  \
# 22   1110089245         1180
# 41   1092313319         1180
# 106  1312712907         1180
# 154  1309774406         1180
# 524   968831698         1180
# 666  1211830337         1180
# 721   345655117         1180
# 747  1301850198         1180
# 764   975261028         1180
# 999   846816060         1180
#
#                                      designation_clean  \
# 22   le seigneur des anneaux figurine en plomb à pe...
# 41                  présentoir à biscuits et chocolats
# 106  comtes vampires lahmiane à pied et montée lahm...
# 154     mournblade ecran et cartes des jeunes royaumes
# 524  warhammer 40000 40k exo armure xv88 broadside ...
# 666                 greyhawk ad d the adventure begins
# 721                             rage across the amazon
# 747  masque halloween masques led glow light up mas...
# 764  vert intérieur p010 gamme air pot de 17ml prin...
# 999                          red steel savage baronies
#
#                                      description_clean
# 22
# 41
# 106
# 154
# 524  ce kit contient 91 composants en plastique ain...
# 666
# 721
# 747  masque halloween led masques glow masque effra...
# 764
# 999  daring swashbucklers stout mercenaries rugged ...
# 22                        Le Seigneur Des Anneaux Figurine En Plomb À Peindre Avec Son Socle : Sam
# 41                                                              Présentoir À Biscuits Et Chocolats
# 106                                Comtes Vampires Lahmiane À Pied Et Montée Lahmia Vampire Counts
# 154                                               Mournblade - Ecran Et Cartes Des Jeunes Royaumes
# 524                                    Warhammer 40000 ( 40k ) - Exo Armure Xv88 Broadside (56-15)
# 666                                                             Greyhawk Ad&d The Adventure Begins
# 721                                                                         Rage Across The Amazon
# 747    Masque Halloween Masques Led Glow Light Up Masque Effrayant Masque De Danse Érogène@Hpp5006
# 764                                    Vert Intérieur P010 Gamme Air - Pot De 17ml - Prince August
# 999                                                                    Red Steel - Savage Baronies
# Name: designation, dtype: str

# %%
df["prdtypecode"].nunique()
# Out:
# 27

# %%
df["prdtypecode"].value_counts().head(10)
# Out:
# prdtypecode
# 2583    10209
# 1560     5073
# 1300     5045
# 2060     4993
# 2522     4989
# 1280     4870
# 2403     4774
# 2280     4760
# 1920     4303
# 1160     3953
# Name: count, dtype: int64

# %%
df["prdtypecode"].describe()
# Out:
# count    84916.000000
# mean      1773.219900
# std        788.179885
# min         10.000000
# 25%       1281.000000
# 50%       1920.000000
# 75%       2522.000000
# max       2905.000000
# Name: prdtypecode, dtype: float64

# %%
import matplotlib.pyplot as plt

df["prdtypecode"].value_counts().head(20).plot(kind="bar")
plt.title("Top 20 most frequent product categories")
plt.show()

# %%
# least represented categories:

df["prdtypecode"].value_counts().tail(7).sort_values().plot(kind="bar")
plt.title("Top 7 least frequent product categories")
plt.show()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# designation        0
# description    29800
# productid          0
# imageid            0
# prdtypecode        0
# dtype: int64

# %%
missing_desc = df["description"].isnull().mean()*100
print("Missing description (%):", missing_desc)
# Out:
# Missing description (%): 35.09350416882566

# %%
df["designation_length"] = df["designation"].str.len()
df["description_length"] = df["description"].str.len()

df[["designation_length","description_length"]].describe()
# Out:
#        designation_length  description_length
# count        84916.000000        55116.000000
# mean            70.163303          808.171692
# std             36.793383          805.462153
# min             11.000000            1.000000
# 25%             43.000000          259.000000
# 50%             64.000000          626.000000
# 75%             90.000000         1034.000000
# max            250.000000        12451.000000

# %%
import matplotlib.pyplot as plt

df["designation_length"].hist(bins=50)
plt.title("Distribution of designation length")
plt.xlabel("Number of characters")
plt.ylabel("Frequency")
plt.show()

# %%
train_images = os.listdir("images/image_train")
test_images = os.listdir("images/image_test")

print("Number of training images:", len(train_images))
print("Number of test images:", len(test_images))
# Out:
# Number of training images: 84916
# Number of test images: 13812

# %%
train_images[:10]
# Out:
# ['image_1000076039_product_580161.jpg',
#  'image_1000089455_product_348990858.jpg',
#  'image_1000092894_product_353108104.jpg',
#  'image_1000093804_product_343306951.jpg',
#  'image_1000095646_product_344209267.jpg',
#  'image_1000095647_product_148177050.jpg',
#  'image_1000099971_product_352683003.jpg',
#  'image_1000100220_product_352601770.jpg',
#  'image_1000222973_product_351172420.jpg',
#  'image_1000228891_product_355017693.jpg']

# %%
for i in range(5):
    row = df.iloc[i]
    image_name = f"image_{row.imageid}_product_{row.productid}.jpg"
    print(image_name in train_images)
# Out:
# True
# True
# True
# True
# True

# %%
correct = 0

for _, row in df.iterrows():
    image_name = f"image_{row.imageid}_product_{row.productid}.jpg"
    
    if image_name in train_images:
        correct += 1

print(f"{correct} out of {len(df)} correct")
# Out:
# 84916 out of 84916 correct

# %%
df["designation"].head(10)
# Out:
# 0    Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1    Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2    Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3    Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                                 La Guerre Des Tuques
# 5    Afrique Contemporaine N° 212 Hiver 2004 - Doss...
# 6           Christof E: Bildungsprozessen Auf Der Spur
# 7    Conquérant Sept Cahier Couverture Polypro 240 ...
# 8            Puzzle Scooby-Doo Avec Poster 2x35 Pieces
# 9    Tente Pliante V3s5-Pro Pvc Blanc - 3 X 4m50 - ...
# Name: designation, dtype: str

# %%
df["designation"].sample(10, random_state=42)
# Out:
# 36138                Nk Pro Racing - Jeu En Téléchargement
# 68630                            Exit - Tombeau Du Pharaon
# 36172    Bricolage Lettres En Mousse D'argent Alphabet ...
# 9830     Nostalgique Fer Blanc Clockwork Chaîne Jouet P...
# 28422    Le Courrier De L'unesco Mai 1996  N° 9605 : Le...
# 25246    Maquette D'avion Multi-Rotor Dispositif De Lan...
# 9314            Le Parisien Magazine 21931 Du 13 Mars 2015
# 24376                      Oxygène shock 3 en 1 - OOGARDEN
# 39184    Decoration De Noel 2019 Joyeux Noël Salle De M...
# 16038    Les Douze Signes Du Zodiaque Dans Toutes Leurs...
# Name: designation, dtype: str

# %%
df["designation"].str.len().describe()
# Out:
# count    84916.000000
# mean        70.163303
# std         36.793383
# min         11.000000
# 25%         43.000000
# 50%         64.000000
# 75%         90.000000
# max        250.000000
# Name: designation, dtype: float64

# %%
df["designation"].isnull().sum()
# Out:
# np.int64(0)

# %%
def clean_txt_colmn(dtfrme, column):    
    new = column + "_clean"    
    # replacing NaNs with empty strings
    dtfrme[new] = dtfrme[column].fillna("")    
    # remove html tags
    dtfrme[new] = dtfrme[new].str.replace(r"<.*?>", " ", regex=True)    
    # decode html entities &amp
    dtfrme[new] = dtfrme[new].str.replace(r"&\w+;", " ", regex=True)    
    # lowercase
    dtfrme[new] = dtfrme[new].str.lower()    
    # remove punctuation and special characters la parantheses fe
    dtfrme[new] = dtfrme[new].str.replace(r"[^\w\s]", " ", regex=True)    
    # normalize spaces
    dtfrme[new] = dtfrme[new].str.replace(r"\s+", " ", regex=True)    
    # strip
    dtfrme[new] = dtfrme[new].str.strip()
    return dtfrme
    

clean_txt_colmn(df,"designation")
clean_txt_colmn(df,"description")
# Out:
#        Unnamed: 0                                        designation  \
# 0               0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1               1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2               2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3               3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4               4                               La Guerre Des Tuques
# ...           ...                                                ...
# 84911       84911                        The Sims [ Import Anglais ]
# 84912       84912  Kit piscine acier NEVADA déco pierre Ø 3.50m x...
# 84913       84913  Journal Officiel De La Republique Francaise N°...
# 84914       84914  Table Basse Bois De Récupération Massif Base B...
# 84915       84915  Gomme De Collection 2 Gommes Pinguin Glace Ver...
#
#                                              description   productid  \
# 0                                                    NaN  3804725264
# 1                                                    NaN   436067568
# 2      PILOT STYLE Touch Pen de marque Speedlink est ...   201115110
# 3                                                    NaN    50418756
# 4      Luc a des id&eacute;es de grandeur. Il veut or...   278535884
# ...                                                  ...         ...
# 84911                                                NaN   206719094
# 84912  <b>Description complète :</b><br />Kit piscine...  3065095706
# 84913                                                NaN   440707564
# 84914  <p>Cette table basse a un design unique et con...  3942400296
# 84915                                                NaN    57203227
#
#           imageid  prdtypecode  \
# 0      1263597046           10
# 1      1008141237         2280
# 2       938777978           50
# 3       457047496         1280
# 4      1077757786         2705
# ...           ...          ...
# 84911   941495734           40
# 84912  1188462883         2583
# 84913  1009325617         2280
# 84914  1267353403         1560
# 84915   684671297         2522
#
#                                        designation_clean  \
# 0      olivia personalisiertes notizbuch 150 seiten p...
# 1      journal des arts le n 133 du 28 09 2001 l art ...
# 2      grand stylet ergonomique bleu gamepad nintendo...
# 3      peluche donald europe disneyland 2000 marionne...
# 4                                   la guerre des tuques
# ...                                                  ...
# 84911                            the sims import anglais
# 84912  kit piscine acier nevada déco pierre ø 3 50m x...
# 84913  journal officiel de la republique francaise n ...
# 84914  table basse bois de récupération massif base b...
# 84915  gomme de collection 2 gommes pinguin glace ver...
#
#                                        description_clean  \
# 0
# 1
# 2      pilot style touch pen de marque speedlink est ...
# 3
# 4      luc a des id es de grandeur il veut organiser ...
# ...                                                  ...
# 84911
# 84912  description complète kit piscine hors sol toi ...
# 84913
# 84914  cette table basse a un design unique et consti...
# 84915
#
#                                                   tokens  \
# 0      [olivia, personalisiertes, notizbuch, 150, sei...
# 1      [journal, des, arts, le, n, 133, du, 28, 09, 2...
# 2      [grand, stylet, ergonomique, bleu, gamepad, ni...
# 3      [peluche, donald, europe, disneyland, 2000, ma...
# 4                              [la, guerre, des, tuques]
# ...                                                  ...
# 84911                       [the, sims, import, anglais]
# 84912  [kit, piscine, acier, nevada, déco, pierre, ø,...
# 84913  [journal, officiel, de, la, republique, franca...
# 84914  [table, basse, bois, de, récupération, massif,...
# 84915  [gomme, de, collection, 2, gommes, pinguin, gl...
#
#        designation_clean_length  description_clean_length  descr_dup_block  \
# 0                            11                         0            False
# 1                            38                         0            False
# 2                            11                       109            False
# 3                             8                         0            False
# 4                             4                        38            False
# ...                         ...                       ...              ...
# 84911                         4                         0            False
# 84912                        12                       153            False
# 84913                        32                         0            False
# 84914                         9                       281            False
# 84915                         9                         0            False
#
#        desig_dup_block                                  description_dedup  \
# 0                False
# 1                False
# 2                False  pilot style touch pen de marque speedlink est ...
# 3                False
# 4                False  luc a des id es de grandeur il veut organiser ...
# ...                ...                                                ...
# 84911            False
# 84912            False  description complète kit piscine hors sol toi ...
# 84913            False
# 84914            False  cette table basse a un design unique et consti...
# 84915            False
#
#        description_dedup_length_chars  description_dedup_length_words  \
# 0                                   0                               0
# 1                                   0                               0
# 2                                 663                             109
# 3                                   0                               0
# 4                                 180                              38
# ...                               ...                             ...
# 84911                               0                               0
# 84912                             941                             153
# 84913                               0                               0
# 84914                            1521                             281
# 84915                               0                               0
#
#        removed_chars  removed_words  description_dedup_length
# 0                  0              0                         0
# 1                  0              0                         0
# 2                  0              0                       109
# 3                  0              0                         0
# 4                  0              0                        38
# ...              ...            ...                       ...
# 84911              0              0                         0
# 84912              0              0                       153
# 84913              0              0                         0
# 84914              0              0                       281
# 84915              0              0                         0
#
# [84916 rows x 19 columns]

# %%
# statistics on characters

df["designation_clean_length"] = df["designation_clean"].str.len()
df["description_clean_length"] = df["description_clean"].str.len()

df[["designation_clean_length","description_clean_length"]].describe()
# Out:
#        designation_clean_length  description_clean_length
# count              84916.000000              84916.000000
# mean                  68.126655                481.740332
# std                   35.273709                690.991373
# min                    9.000000                  0.000000
# 25%                   41.000000                  0.000000
# 50%                   62.000000                211.000000
# 75%                   89.000000                767.000000
# max                  246.000000              12142.000000

# %%
df.loc[df["description_clean_length"].idxmax(), "description_clean"]
df.loc[df["description_clean_length"].idxmax()]
# Out:
# Unnamed: 0                                                              61512
# designation                 Doauhao®Lumineux Pvc Téléphone Mobile Sac Étan...
# description                 Lumineux Pvc Téléphone mobile Sac étanche camé...
# productid                                                          4023550194
# imageid                                                            1277618412
# prdtypecode                                                              1560
# designation_clean           doauhao lumineux pvc téléphone mobile sac étan...
# description_clean           lumineux pvc téléphone mobile sac étanche camé...
# tokens                      [doauhao, lumineux, pvc, téléphone, mobile, sa...
# designation_clean_length                                                   84
# description_clean_length                                                12142
# Name: 61512, dtype: object

# %%
df.loc[64317, "description_clean"]
# Out:
# 'réaliste reborn 55cm reborn lifelike en vinyle souple en silicone noël fonction actuelle doll taille 55cm poupée réaliste est fait à la main réincarné doll the sera une erreur de la taille et de la tête aux pieds weight from avec une vraie touche de la tête de vinyle le visage et les membres corps lesté pour un vrai bébé feel baby peut s 39 insère dans des vêtements de bébé nouveau né la taille de 0 3m matériel sûr et tactile sentiment réel cette poupée bébé réaliste est livré avec un corps en tissu doux pondérée pour la sensation la plus réaliste lorsque vous blottir contre lui la poupée à la main peut s 39 asseoir et se coucher mais ne peut pas se tenir debout pleurer rire parler ou manger les membres sont poseable she a de beaux détails peints à la main la main appliquée cils et cheveux magnifiques handrooted doux bébé like mieux que poupées vinyl ordinaires les membres sont nuisette movable reborn pouvez vous asseoir et poser facilement mais ne supporte pas parler ou être lavés belle main mis les yeux bruns cheveux bruns foncés la main appliquée cils et peint à la main les détails sur ses doigts et les yeux toes the ne peut clignoter ou fermer collector et maman meilleur choix les cheveux peuvent être lavés et dressed if les cheveux est un peu désordonné s 39 il vous plaît utiliser le peigne perruque spéciale pour prendre soin gently conforms aux exigences de sécurité de la norme astm f963 et en71 pour 3 ans cadeaux festival cadeaux d 39 anniversaire les enfants jouent avec des jouets grand papa ou grand mère accompagne collection de poupées amateurs et collectionneurs ce bambin sécurité non toxique fille poupée est grande pour les enfants jouent avec des jouets grand père ou grand mère accompagnez poupée cadeaux de noël cadeaux d 39 anniversaire commandez maintenant et prenez l 39 amour à la maison contenu d 39 emballage 1 x 1 poupée bébé reborn x un ensemble de costumes tout comme l 39 image 1 x aimant pacifier 1 x accessoire cheveux 1 x biberon 1 x 1 x coussins peigne cheveux bruns foncés la main appliquée cils et peint à la main les détails sur ses doigts et les yeux toes the ne peut clignoter ou fermer collector et maman meilleur choix les cheveux peuvent être lavés et dressed if les cheveux est un peu désordonné s 39 il vous plaît utiliser le peigne perruque spéciale pour prendre soin gently conforms aux exigences de sécurité de la norme astm f963 et en71 pour 3 ans cadeaux festival cadeaux d 39 anniversaire les enfants jouent avec des jouets grand papa ou grand mère accompagne collection de poupées amateurs et collectionneurs ce bambin sécurité non toxique fille poupée est grande pour les enfants jouent avec des jouets grand père ou grand mère accompagnez poupée cadeaux de noël cadeaux d 39 anniversaire commandez maintenant et prenez l 39 amour à la maison contenu d 39 emballage 1 x 1 poupée bébé reborn x un ensemble de costumes tout comme l 39 image 1 x aimant pacifier 1 x accessoire cheveux 1 x biberon 1 x 1 x coussins peigne cheveux bruns foncés la main appliquée cils et peint à la main les détails sur ses doigts et les yeux toes the ne peut clignoter ou fermer collector et maman meilleur choix les cheveux peuvent être lavés et dressed if les cheveux est un peu désordonné s 39 il vous plaît utiliser le peigne perruque spéciale pour prendre soin gently conforms aux exigences de sécurité de la norme astm f963 et en71 pour 3 ans cadeaux festival cadeaux d 39 anniversaire les enfants jouent avec des jouets grand papa ou grand mère accompagne collection de poupées amateurs et collectionneurs ce bambin sécurité non toxique fille poupée est grande pour les enfants jouent avec des jouets grand père ou grand mère accompagnez poupée cadeaux de noël cadeaux d 39 anniversaire commandez maintenant et prenez l 39 amour à la maison contenu d 39 emballage 1 x 1 poupée bébé reborn x un ensemble de costumes tout comme l 39 image 1 x aimant pacifier 1 x accessoire cheveux 1 x biberon 1 x 1 x coussins peigne peint à la main cils et ...

# %%
# the image which has a description of 12K characters

from PIL import Image
import matplotlib.pyplot as plt
import os


filename = f"image_train/image_1277618412_product_4023550194.jpg"
path = os.path.join("images", filename)   # change folder if needed

img = Image.open(path)

plt.imshow(img)
plt.title(filename)
plt.axis("off")
plt.show()

# %%
# top 10 longest descriptions
df.nlargest(10, "description_clean_length")[["Unnamed: 0", "productid", "imageid", "description_clean_length"]]
# Out:
#        Unnamed: 0   productid     imageid  description_clean_length
# 61512       61512  4023550194  1277618412                     12142
# 64317       64317  4006510427  1275646331                      9967
# 47398       47398  4053879512  1282015512                      9201
# 80661       80661  4050860415  1281450969                      9201
# 79814       79814  3883412829  1257934991                      9190
# 75450       75450  2017625800  1120710643                      9182
# 25474       25474  3868888014  1255182649                      9122
# 84021       84021  4184608532  1310877211                      8938
# 57160       57160  3951727598  1268596331                      8875
# 12085       12085  4187125541  1311446278                      8844

# %%
# statistics on tokens

df["designation_clean_length"] = df["designation_clean"].str.split().str.len()
df["description_clean_length"] = df["description_clean"].str.split().str.len()

df[["designation_clean_length","description_clean_length"]].describe()
# Out:
#        designation_clean_length  description_clean_length
# count              84916.000000              84916.000000
# mean                  11.538191                 83.780689
# std                    6.037529                121.220067
# min                    2.000000                  0.000000
# 25%                    7.000000                  0.000000
# 50%                   11.000000                 36.000000
# 75%                   14.000000                132.000000
# max                   51.000000               2211.000000

# %%
df["designation_clean_length"] = df["designation_clean"].str.split().str.len()
df["description_clean_length"] = df["description_clean"].str.split().str.len()

fig, axes = plt.subplots(1, 2, figsize=(12,5))

df["designation_clean_length"].hist(bins=50, ax=axes[0])
axes[0].set_title("Distribution of designation_clean token count")
axes[0].set_xlabel("Number of tokens")
axes[0].set_ylabel("Frequency")

df["description_clean_length"].hist(bins=50, ax=axes[1])
axes[1].set_title("Distribution of description_clean token count")
axes[1].set_xlabel("Number of tokens")
axes[1].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
import numpy as np

# lengths
df["designation_clean_length"] = df["designation_clean"].str.split().str.len()
desc_nonempty = df.loc[df["description_clean"].str.strip() != "", "description_clean"]
desc_nonempty_len = desc_nonempty.str.split().str.len()

def outlier_ratio(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    outliers = ((series < lower) | (series > upper)).sum()
    return outliers / len(series)

ratio_design = outlier_ratio(df["designation_clean_length"])
ratio_descr  = outlier_ratio(desc_nonempty_len)

fig, axes = plt.subplots(1, 2, figsize=(12,5))

# designation
df["designation_clean_length"].plot.box(ax=axes[0])
axes[0].set_title("designation_clean token count")
axes[0].set_ylabel("Number of tokens")
axes[0].text(
    0.65, 0.92,                      # inside the plot area (right/top)
    f"Outliers: {ratio_design:.2%}",
    transform=axes[0].transAxes,
    ha="left", va="center",
    bbox=dict(facecolor="white", alpha=0.7, edgecolor="none")
)

# description (non-empty only)
desc_nonempty_len.plot.box(ax=axes[1])
axes[1].set_title("description_clean token count\n(non-empty only)")
axes[1].set_ylabel("Number of tokens")
axes[1].text(
    0.65, 0.92,
    f"Outliers: {ratio_descr:.2%}",
    transform=axes[1].transAxes,
    ha="left", va="center",
    bbox=dict(facecolor="white", alpha=0.7, edgecolor="none")
)

plt.tight_layout()
plt.show()

# %%
# search for copied block of text in textual columns

import re

def has_repeated_block(text, min_block_len=100):
    if not isinstance(text, str):
        return False
    text = text.strip()
    if len(text) < min_block_len * 2:
        return False
    # look for a block repeated at least twice
    pattern = rf"(.{{{min_block_len},}})\1+"
    return re.search(pattern, text) is not None

# detect rows with repeated blocks
df["descr_dup_block"] = df["description_clean"].apply(has_repeated_block)
df["desig_dup_block"] = df["designation_clean"].apply(has_repeated_block)

# summary
print("Rows with duplicated blocks in description:", df["descr_dup_block"].sum())
print("Percentage affected:", round(100 * df["descr_dup_block"].mean(), 2), "%")
print("\n\nRows with duplicated blocks in designation:", df["desig_dup_block"].sum())
print("Percentage affected:", round(100 * df["desig_dup_block"].mean(), 2), "%")
# Out:
# Rows with duplicated blocks in description: 1232
# Percentage affected: 1.45 %
#
#
# Rows with duplicated blocks in designation: 0
# Percentage affected: 0.0 %

# %%
# inspect a few examples

import re

def find_repeated_blocks(text, min_block_len=80):
    """
    Detect consecutive repeated blocks in a text.
    Returns: (block, repetitions, block_length)
    """
    if not isinstance(text, str):
        return []

    pattern = re.compile(r"(.{" + str(min_block_len) + r",}?)(\1+)", re.DOTALL)

    matches = []

    for m in pattern.finditer(text):
        block = m.group(1)
        repeated = m.group(2)

        repetitions = 1 + len(repeated) // len(block)

        matches.append((block, repetitions, len(block)))

    return matches


top5 = df.nlargest(5, "description_clean_length")[[
    "Unnamed: 0",
    "description_clean_length",
    "description_clean"
]]

for _, row in top5.iterrows():

    print("="*100)
    print("ID:", row["Unnamed: 0"])
    print("Description length:", row["description_clean_length"])

    repeated_blocks = find_repeated_blocks(row["description_clean"], 80)

    if not repeated_blocks:
        print("No repeated blocks found.")
        continue

    print("Repeated blocks found:", len(repeated_blocks))

    for i, (block, reps, block_len) in enumerate(repeated_blocks[:5], 1):

        print("-"*80)
        print("Block", i)
        print("Block length:", block_len)
        print("Repetitions:", reps)
        print("Preview:")
        print(block[:300])

        if len(block) > 300:
            print("...")
# Out:
# ====================================================================================================
# ID: 61512
# Description length: 2211
# Repeated blocks found: 6
# --------------------------------------------------------------------------------
# Block 1
# Block length: 904
# Repetitions: 2
# Preview:
#  facile à utiliser le téléphone est très pratique donc le cas de téléphone d 39 un téléphone devrait aider à conduire le même développement il suffit de glisser le bouton du haut pour ouvrir et fermer le couvercle du téléphone cela vous permet de glisser votre téléphone ou en quelques secondes acces
# ...
# --------------------------------------------------------------------------------
# Block 2
# Block length: 899
# Repetitions: 5
# Preview:
#  facile à utiliser le téléphone est très pratique donc le cas de téléphone d 39 un téléphone devrait aider à conduire le même développement il suffit de glisser le bouton du haut pour ouvrir et fermer le couvercle du téléphone cela vous permet de glisser votre téléphone ou en quelques secondes acces
# ...
# --------------------------------------------------------------------------------
# Block 3
# Block length: 858
# Repetitions: 2
# Preview:
#  de sorte que le cas de téléphone d 39 un téléphone devrait aider à conduire le même développement il suffit de glisser le bouton du haut pour ouvrir et fermer le couvercle du téléphone cela vous permet de glisser votre téléphone ou en quelques secondes accessibilité ce cas de téléphone n 39 a pas à
# ...
# --------------------------------------------------------------------------------
# Block 4
# Block length: 760
# Repetitions: 2
# Preview:
#  il suffit de glisser le bouton du haut pour ouvrir et fermer le couvercle du téléphone cela vous permet de glisser votre téléphone ou en quelques secondes accessibilité ce cas de téléphone n 39 a pas à se soucier de minimiser l 39 affichage de l 39 écran ou de protection de la plage de la caméra ce
# ...
# --------------------------------------------------------------------------------
# Block 5
# Block length: 605
# Repetitions: 2
# Preview:
#  accessibilité ce cas de téléphone n 39 a pas à se soucier de minimiser l 39 affichage de l 39 écran ou de protection de la plage de la caméra ce cas de téléphone est conçu pour utiliser votre téléphone de manière aussi transparente que possible un espace suffisant ce cas de téléphone correspond à u
# ...
# ====================================================================================================
# ID: 64317
# Description length: 1793
# Repeated blocks found: 5
# --------------------------------------------------------------------------------
# Block 1
# Block length: 983
# Repetitions: 3
# Preview:
#  cheveux bruns foncés la main appliquée cils et peint à la main les détails sur ses doigts et les yeux toes the ne peut clignoter ou fermer collector et maman meilleur choix les cheveux peuvent être lavés et dressed if les cheveux est un peu désordonné s 39 il vous plaît utiliser le peigne perruque
# ...
# --------------------------------------------------------------------------------
# Block 2
# Block length: 967
# Repetitions: 2
# Preview:
#  peint à la main cils et appliqués à la main les détails sur ses doigts et toes the les yeux ne peuvent clignoter ou fermer collector et maman meilleur choix les cheveux peuvent être lavés et dressed if les cheveux est un peu désordonné s 39 il vous plaît utiliser le peigne perruque spéciale pour pr
# ...
# --------------------------------------------------------------------------------
# Block 3
# Block length: 872
# Repetitions: 2
# Preview:
#  t clignotent ou à proximité collector et maman meilleur choix les cheveux peuvent être lavés et dressed if les cheveux est un peu désordonné s 39 il vous plaît utiliser le peigne perruque spéciale pour prendre soin gently conforms aux exigences de sécurité de la norme astm f963 et en71 pour 3 ans c
# ...
# --------------------------------------------------------------------------------
# Block 4
# Block length: 747
# Repetitions: 2
# Preview:
#  s 39 il vous plaît utiliser le peigne perruque spéciale pour prendre soin gently conforms aux exigences de sécurité de la norme astm f963 et en71 pour 3 ans et 43 cadeaux festival cadeaux d 39 anniversaire les enfants jouent avec des jouets grand papa ou grand mère accompagnent collection de poupée
# ...
# --------------------------------------------------------------------------------
# Block 5
# Block length: 410
# Repetitions: 2
# Preview:
#  ce bambin sécurité non toxique fille poupée est grande pour les enfants jouent avec des jouets grand père ou grand mère accompagnez poupée cadeaux de noël cadeaux d 39 anniversaire commandez maintenant et prenez l 39 amour à la maison contenu d 39 emballage 1 x 1 poupée bébé reborn x un ensemble de
# ...
# ====================================================================================================
# ID: 25474
# Description length: 1714
# Repeated blocks found: 5
# --------------------------------------------------------------------------------
# Block 1
# Block length: 730
# Repetitions: 3
# Preview:
#  dans ce cas la lampe solaire ne peut pas rester allumé le temps donné ce dispositif est lumière dirigée à l 39 énergie solaire la lampe éclaire lorsqu 39 elle est chargée par le soleil les conditions de soleil affecteront l 39 éclairage de la lampe il ne doit pas être comparé à aucun projecteur ou
# ...
# --------------------------------------------------------------------------------
# Block 2
# Block length: 715
# Repetitions: 2
# Preview:
#  lampe solaire ne peut pas rester allumé le temps donné ce dispositif est lumière dirigée à l 39 énergie solaire la lampe éclaire lorsqu 39 elle est chargée par le soleil les conditions de soleil affecteront l 39 éclairage de la lampe il ne doit pas être comparé à aucun projecteur ou projecteur qui
# ...
# --------------------------------------------------------------------------------
# Block 3
# Block length: 603
# Repetitions: 2
# Preview:
#  la lampe éclaire lorsqu 39 elle est chargée par le soleil les conditions de soleil affecteront l 39 éclairage de la lampe il ne doit pas être comparé à aucun projecteur ou projecteur qui est alimenté par d 39 autres sources d 39 énergie avertissement gardez l 39 appareil loin du feu afin d 39 évite
# ...
# --------------------------------------------------------------------------------
# Block 4
# Block length: 481
# Repetitions: 2
# Preview:
#  il ne doit pas être comparé à aucun projecteur ou projecteur qui est alimenté par d 39 autres sources d 39 énergie avertissement gardez l 39 appareil loin du feu afin d 39 éviter une explosion tout battement sévère ou de choc au chargeur n 39 est pas recommandé démontez au chargeur n 39 est pas rec
# ...
# --------------------------------------------------------------------------------
# Block 5
# Block length: 219
# Repetitions: 2
# Preview:
#  démontez au chargeur n 39 est pas recommandé en cas d 39 endommager l 39 appareil le paquet contient 1 pc solaire pir motion sensor nbsp led lampe 2 pc ancres à vis en plastique 2 vis pc 1 pc manuel de l 39 utilisateur
# ====================================================================================================
# ID: 79814
# Description length: 1679
# Repeated blocks found: 5
# --------------------------------------------------------------------------------
# Block 1
# Block length: 924
# Repetitions: 2
# Preview:
#  le jouet de voiturette de golf favorisera également le développement mental de votre enfant golf prend beaucoup de concentration de la patience et de manières afin de jouer avec ces clubs et balles de golf permettra d 39 améliorer votre observation de gosse l 39 imagination et les compétences de ju
# ...
# --------------------------------------------------------------------------------
# Block 2
# Block length: 899
# Repetitions: 3
# Preview:
#  le jouet de voiturette de golf favorisera également le développement mental de votre enfant golf prend beaucoup de concentration de la patience et de manières afin de jouer avec ces clubs et balles de golf permettra d 39 améliorer votre observation de gosse l 39 imagination et les compétences de ju
# ...
# --------------------------------------------------------------------------------
# Block 3
# Block length: 807
# Repetitions: 2
# Preview:
#  golf prend beaucoup de concentration de la patience et de manières afin de jouer avec ces clubs et balles de golf permettra d 39 améliorer votre observation de gosse l 39 imagination et les compétences de jugement et il les aidera à adopter la culture de la concurrence saine tout parent voudrait ce
# ...
# --------------------------------------------------------------------------------
# Block 4
# Block length: 624
# Repetitions: 2
# Preview:
#  et les compétences de jugement et il les aidera à adopter la culture de la concurrence saine tout parent voudrait ces choses pour leur enfant un don que tout kid et parent aimerait le jouet du club de golf enfant est un grand cadeau pour les enfants qu 39 ils soient filles ou garçons si vous donnez
# ...
# --------------------------------------------------------------------------------
# Block 5
# Block length: 339
# Repetitions: 2
# Preview:
#  si vous donnez les jouets de golf mis à un enfant dans votre famille vous pouvez être sûr que aussi les parents vont adorer le jouet balle de golf pourrait être un excellent moyen pour les parents de passer du temps de qualité avec leurs enfants et d 39 obligations plus comme ils leur apprendre à j
# ...
# ====================================================================================================
# ID: 84021
# Description length: 1678
# Repeated blocks found: 5
# --------------------------------------------------------------------------------
# Block 1
# Block length: 941
# Repetitions: 3
# Preview:
#  il peut jouer à des jeux pendant la charge évitant ainsi le problème des jeux étagères lors du chargement selon les exigences du jeu les poignées multiples peuvent être connectés à jouer à des jeux multijoueurs design ergonomique et la construction de poignée légère font les joueurs se sentent à l
# ...
# --------------------------------------------------------------------------------
# Block 2
# Block length: 895
# Repetitions: 2
# Preview:
#  en évitant le problème des jeux étagères lors du chargement selon les exigences du jeu les poignées multiples peuvent être connectés à jouer à des jeux multijoueurs design ergonomique et la construction de poignée légère font les joueurs se sentent à l 39 aise même si elles jouent le jeu en continu
# ...
# --------------------------------------------------------------------------------
# Block 3
# Block length: 804
# Repetitions: 2
# Preview:
#  plusieurs poignées peuvent être connectés à jouer à des jeux multijoueurs design ergonomique et la construction de poignée légère font les joueurs se sentent à l 39 aise même si elles jouent le jeu en continu pendant une longue période ils ne se sentent pas fatigués cette poignée peut être mis à ni
# ...
# --------------------------------------------------------------------------------
# Block 4
# Block length: 634
# Repetitions: 2
# Preview:
#  même si elles jouent le jeu en continu pendant une longue période ils ne se sentent pas fatigués cette poignée peut être mis à niveau en connectant l 39 ordinateur avec le logiciel de mise à niveau specificationthe intégré 380 ma batterie au lithium polymère peut fonctionner pendant environ 5 heure
# ...
# --------------------------------------------------------------------------------
# Block 5
# Block length: 207
# Repetitions: 2
# Preview:
#  dc 5v 500ma tension de travail dc 3 7 4 2v courant de fonctionnement 20 30 ma courant de vibration 80 130 ma taille 163 x 1125 x 55 mm poids net 290 g le paquet contient 1x jeu handl 1x ligne de données usb

# %%
# removing repeating text blocks in description

import re

def remove_repeated_blocks(text, min_block_len=100):
    """
    Remove consecutively repeated text blocks of length >= min_block_len.
    Keeps the first occurrence only.
    """
    if not isinstance(text, str):
        return text

    text = text.strip()
    if len(text) < 2 * min_block_len:
        return text

    # build regex safely
    pattern = re.compile(r"(.{" + str(min_block_len) + r",}?)(?:\1)+", re.DOTALL)

    previous = None
    while text != previous:
        previous = text

        # collapse repeated consecutive blocks
        text = pattern.sub(r"\1", text)

        # normalize spaces created during replacement
        text = re.sub(r"\s+", " ", text).strip()

    return text


# apply only to descriptions
df["description_dedup"] = df["description_clean"].apply(remove_repeated_blocks)

# compare before vs after
df["description_dedup_length_chars"] = df["description_dedup"].str.len()
df["description_dedup_length_words"] = df["description_dedup"].str.split().str.len()

df["removed_chars"] = df["description_clean"].str.len() - df["description_dedup_length_chars"]
df["removed_words"] = df["description_clean"].str.split().str.len() - df["description_dedup_length_words"]

# summary
affected_after_cleaning = (df["removed_chars"] > 0).sum()

print("Rows changed after deduplication:", affected_after_cleaning)
print("Percentage changed:", round(100 * affected_after_cleaning / len(df), 2), "%")

display(
    df.loc[df["removed_chars"] > 0,["Unnamed: 0", "description_clean_length", "description_dedup_length_words", "removed_words", "removed_chars"]].sort_values("removed_chars", ascending=False).head(10))
# Out:
# Rows changed after deduplication: 1232
# Percentage changed: 1.45 %
#        Unnamed: 0  description_clean_length  description_dedup_length_words  \
# 61512       61512                      2211                             626
# 64087       64087                      1494                             370
# 79814       79814                      1679                             520
# 65613       65613                      1562                             358
# 14596       14596                      1494                             437
# 80661       80661                      1597                             586
# 47398       47398                      1597                             586
# 25474       25474                      1714                             652
# 64317       64317                      1793                             825
# 76541       76541                      1052                             138
#
#        removed_words  removed_chars
# 61512           1585           8622
# 64087           1124           6568
# 79814           1159           6262
# 65613           1204           6196
# 14596           1057           5894
# 80661           1011           5789
# 47398           1011           5789
# 25474           1062           5496
# 64317            968           5372
# 76541            914           5352

# %%
# token lengths
df["description_clean_length"] = df["description_clean"].str.split().str.len()
df["description_dedup_length"] = df["description_dedup"].str.split().str.len()

# exclude empty descriptions
desc_clean = df.loc[df["description_clean"].str.strip() != "", "description_clean_length"]
desc_dedup = df.loc[df["description_dedup"].str.strip() != "", "description_dedup_length"]

def box_stats(series):
    q1 = series.quantile(0.25)
    q2 = series.quantile(0.50)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    lower = max(series.min(), q1 - 1.5 * iqr)
    upper = min(series.max(), q3 + 1.5 * iqr)
    outliers = ((series < lower) | (series > upper)).sum()
    ratio = outliers / len(series)
    return q1, q2, q3, lower, upper, ratio

stats_clean = box_stats(desc_clean)
stats_dedup = box_stats(desc_dedup)

fig, axes = plt.subplots(1, 2, figsize=(12,5))

# description_clean
desc_clean.plot.box(ax=axes[0])
axes[0].set_title("description_clean token count (non-empty)")
axes[0].set_ylabel("Number of tokens")

text_clean = (
    f"Q1: {stats_clean[0]:.0f}\n"
    f"Median: {stats_clean[1]:.0f}\n"
    f"Q3: {stats_clean[2]:.0f}\n"
    f"Lower whisker: {stats_clean[3]:.0f}\n"
    f"Upper whisker: {stats_clean[4]:.0f}\n"
    f"Outliers: {stats_clean[5]:.2%}"
)

axes[0].text(
    0.65, 0.6,
    text_clean,
    transform=axes[0].transAxes,
    bbox=dict(facecolor="white", alpha=0.7, edgecolor="none")
)

# description_dedup
desc_dedup.plot.box(ax=axes[1])
axes[1].set_title("description_dedup token count (non-empty)")
axes[1].set_ylabel("Number of tokens")

text_dedup = (
    f"Q1: {stats_dedup[0]:.0f}\n"
    f"Median: {stats_dedup[1]:.0f}\n"
    f"Q3: {stats_dedup[2]:.0f}\n"
    f"Lower whisker: {stats_dedup[3]:.0f}\n"
    f"Upper whisker: {stats_dedup[4]:.0f}\n"
    f"Outliers: {stats_dedup[5]:.2%}"
)

axes[1].text(
    0.65, 0.6,
    text_dedup,
    transform=axes[1].transAxes,
    bbox=dict(facecolor="white", alpha=0.7, edgecolor="none")
)

plt.tight_layout()
plt.show()

# %%
df[["description","description_clean"]].sample(20, random_state=7)
# Out:
#                                              description  \
# 5835   C-Fly RÊVE GPS WIFI FPV Avec 2 axes Gimbal 108...
# 13527                                                NaN
# 8559                                                 NaN
# 24440  4pc citrouille d&#39;Halloween Fantôme Taie Dé...
# 74096  Ces boitiers sont la solution idéale que vous ...
# 74286  ProduttoreBANDAI MODEL KITTipologia ProdottoMO...
# 8455   <p>Lame métallique de rechange pour tondeuses ...
# 62281                                                NaN
# 68149                                                NaN
# 33647  Mandala Fleur Chambre Indian Living Wall Chamb...
# 66724                                                NaN
# 83393  Piscine hors-sol ovale en acier blanc Fidji de...
# 57993  Taille: En format A5 (144 cm x 21 cm) Caractéi...
# 1452   <p>Fauteuil de bureau en simili-cuir bordeaux ...
# 38662                                                NaN
# 938    drap housse JAUNE Quantité : 1 Modèle : TT0102...
# 71378                                                NaN
# 52997  <p>Article neuf générique pour Nintendo N64. E...
# 28930  Vous savez comme il est pénible de gratter la ...
# 34575                                                NaN
#
#                                        description_clean
# 5835   c fly rêve gps wifi fpv avec 2 axes gimbal 108...
# 13527
# 8559
# 24440  4pc citrouille d 39 halloween fantôme taie déc...
# 74096  ces boitiers sont la solution idéale que vous ...
# 74286  produttorebandai model kittipologia prodottomo...
# 8455   lame métallique de rechange pour tondeuses hau...
# 62281
# 68149
# 33647  mandala fleur chambre indian living wall chamb...
# 66724
# 83393  piscine hors sol ovale en acier blanc fidji de...
# 57993  taille en format a5 144 cm x 21 cm caractéisti...
# 1452   fauteuil de bureau en simili cuir bordeaux ave...
# 38662
# 938    drap housse jaune quantité 1 modèle tt01024 ré...
# 71378
# 52997  article neuf générique pour nintendo n64 expéd...
# 28930  vous savez comme il est pénible de gratter la ...
# 34575

# %%
# split each cleaned title into tokens
tokens = df["designation_clean"].str.split()
display(tokens.head())
# convert the list of tokens into a single column of words for an initial distribution count
all_words = tokens.explode()
# let see the first 30
all_words.value_counts().head(30)
# Out:
# 0    [olivia, personalisiertes, notizbuch, 150, sei...
# 1    [journal, des, arts, le, n, 133, du, 28, 09, 2...
# 2    [grand, stylet, ergonomique, bleu, gamepad, ni...
# 3    [peluche, donald, europe, disneyland, 2000, ma...
# 4                            [la, guerre, des, tuques]
# Name: designation_clean, dtype: object
# designation_clean
# de           43543
# pour         11201
# en            9579
# d             9111
# la            8406
# à             8388
# et            7761
# x             6564
# 2             6426
# du            6109
# n             5910
# 1             5865
# l             5725
# le            5587
# cm            4827
# piscine       4778
# les           4320
# lot           4310
# 3             4168
# jeu           4164
# avec          3839
# générique     3770
# coussin       3521
# m             3316
# 4             3265
# des           3156
# kit           2624
# a             2597
# blanc         2409
# rc            2379
# Name: count, dtype: int64

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words(['french', 'english', 'german']))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ion\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def prepare_all_words(df, column, stop_words):

    # tokenize
    tokens = df[column].str.split()

    # flatten into single column of words
    words = tokens.explode()

    # remove stopwords
    words = words[~words.isin(stop_words)]

    # remove short tokens
    words = words[words.str.len() > 2]

    return words

design_words = prepare_all_words(df, "designation_clean", stop_words)
descrp_words = prepare_all_words(df, "description_clean", stop_words)

display(len(design_words.unique()))
display(len(descrp_words.unique()))
# Out:
# 82116
# 136972

# %%
display(design_words.value_counts().head(10))
display(descrp_words.value_counts().head(10))
# Out:
# designation_clean
# piscine      4778
# lot          4310
# jeu          4164
# générique    3770
# coussin      3521
# kit          2624
# blanc        2409
# enfants      2374
# taie         2308
# bois         2245
# Name: count, dtype: int64
# description_clean
# couleur    25309
# taille     24654
# plus       22108
# peut       21881
# eau        19369
# piscine    18518
# haute      18272
# qualité    17000
# être       16759
# 100        14993
# Name: count, dtype: int64

# %%
df[df["designation_clean"].str.contains(r"\d", regex=True)][["designation_clean","description_clean"]].head(10)
# Out:
#                                     designation_clean  \
# 0   olivia personalisiertes notizbuch 150 seiten p...
# 1   journal des arts le n 133 du 28 09 2001 l art ...
# 3   peluche donald europe disneyland 2000 marionne...
# 5   afrique contemporaine n 212 hiver 2004 dossier...
# 7   conquérant sept cahier couverture polypro 240 ...
# 8           puzzle scooby doo avec poster 2x35 pieces
# 9   tente pliante v3s5 pro pvc blanc 3 x 4m50 long...
# 11  fauteuil chesterfield brenton 100 cuir de buff...
# 12  peaceable kingdom wheres bear the hide and fin...
# 14  matelas mémoire de forme 180x200 x 20 cm très ...
#
#                                     description_clean
# 0
# 1
# 3
# 5
# 7   conquerant classique cahier 240 x 320 mm seyès...
# 8
# 9   tente pliante v3s5 pro pvc 500 gr m² 3 x 4m50 ...
# 11  canapé et fauteuil chesterfield en cuir antiqu...
# 12  pcan my 2 year old play a game yes each game i...
# 14  matelas â accueil ferme â soutien très ferme â...

# %%
print(f" there are {filtered_words.nunique()} unique words")
# statistics per words in designation
tokens_filtered = df["designation_clean"].str.split()
tokens_filtered.apply(len).describe()
# Out:
#  there are 82283 unique words
# count    84916.000000
# mean        11.538191
# std          6.037529
# min          2.000000
# 25%          7.000000
# 50%         11.000000
# 75%         14.000000
# max         51.000000
# Name: designation_clean, dtype: float64

# %%
top_categories = df["prdtypecode"].value_counts().head(10).index        # get the 10 most frequent categories
df["tokens"] = df["designation_clean"].str.split()                      # create token lists from titles
df_tokens = df[["prdtypecode","tokens"]].explode("tokens")              # explode tokens so each word becomes a row
df_tokens = df_tokens[~df_tokens["tokens"].isin(stop_words)]            # keep only filtered tokens (no stopwords, length > 2)
df_tokens = df_tokens[df_tokens["tokens"].str.len() > 2]            
df_tokens = df_tokens[df_tokens["prdtypecode"].isin(top_categories)]    # keep only the top 10 categories
                                                                        # compute token frequency per category
token_counts = (df_tokens.groupby(["prdtypecode","tokens"]).size().reset_index(name="count"))

                                                                        # select top 5 tokens per category
top_tokens = (token_counts.sort_values(["prdtypecode","count"], ascending=[True, False]).groupby("prdtypecode").head(5))


for cat in top_categories:    
    data = top_tokens[top_tokens["prdtypecode"] == cat]    
    data.plot(
        x="tokens",
        y="count",
        kind="bar",
        legend=False
    )
    
    plt.title(f"Top tokens for category {cat}")
    plt.ylabel("frequency")
    plt.xlabel("token")
    plt.show();

# %%
# for category 1180
cat_df = df[df["prdtypecode"] == 1180]
tokens = cat_df["designation_clean"].str.split()
words = tokens.explode()
words = words[~words.isin(stop_words)]
words = words[words.str.len() > 2]
top_words = words.value_counts().head(5)
top_words.plot(kind="bar")

plt.title("Top 5 tokens in designation for category 1180")
plt.ylabel("frequency")
plt.xlabel("token")

plt.show()

# %%
# for temporary use 
df_raw_260312 = df.copy()
df_raw_260312.head(10)
df.to_csv("df_raw_260312.csv", index=False)

# %%
df["description_clean_ini"] = df["description_clean"]
df.head(5)
# Out:
#    Unnamed: 0                                        designation  \
# 0           0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1           1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2           2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3           3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4           4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#    prdtypecode                                  designation_clean  \
# 0           10  olivia personalisiertes notizbuch 150 seiten p...
# 1         2280  journal des arts le n 133 du 28 09 2001 l art ...
# 2           50  grand stylet ergonomique bleu gamepad nintendo...
# 3         1280  peluche donald europe disneyland 2000 marionne...
# 4         2705                               la guerre des tuques
#
#                                    description_clean  \
# 0
# 1
# 2  pilot style touch pen de marque speedlink est ...
# 3
# 4  luc a des id es de grandeur il veut organiser ...
#
#                                               tokens  \
# 0  [olivia, personalisiertes, notizbuch, 150, sei...
# 1  [journal, des, arts, le, n, 133, du, 28, 09, 2...
# 2  [grand, stylet, ergonomique, bleu, gamepad, ni...
# 3  [peluche, donald, europe, disneyland, 2000, ma...
# 4                          [la, guerre, des, tuques]
#
#    designation_clean_length  description_clean_length  descr_dup_block  \
# 0                        11                         0            False
# 1                        38                         0            False
# 2                        11                       109            False
# 3                         8                         0            False
# 4                         4                        38            False
#
#    desig_dup_block                                  description_dedup  \
# 0            False
# 1            False
# 2            False  pilot style touch pen de marque speedlink est ...
# 3            False
# 4            False  luc a des id es de grandeur il veut organiser ...
#
#    description_dedup_length_chars  description_dedup_length_words  \
# 0                               0                               0
# 1                               0                               0
# 2                             663                             109
# 3                               0                               0
# 4                             180                              38
#
#    removed_chars  removed_words  description_dedup_length  \
# 0              0              0                         0
# 1              0              0                         0
# 2              0              0                       109
# 3              0              0                         0
# 4              0              0                        38
#
#                                description_clean_ini
# 0
# 1
# 2  pilot style touch pen de marque speedlink est ...
# 3
# 4  luc a des id es de grandeur il veut organiser ...

# %%
df["description_clean"] = df["description_dedup"]
df.head(5)
# Out:
#    Unnamed: 0                                        designation  \
# 0           0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1           1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2           2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3           3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4           4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#    prdtypecode                                  designation_clean  \
# 0           10  olivia personalisiertes notizbuch 150 seiten p...
# 1         2280  journal des arts le n 133 du 28 09 2001 l art ...
# 2           50  grand stylet ergonomique bleu gamepad nintendo...
# 3         1280  peluche donald europe disneyland 2000 marionne...
# 4         2705                               la guerre des tuques
#
#                                    description_clean  \
# 0
# 1
# 2  pilot style touch pen de marque speedlink est ...
# 3
# 4  luc a des id es de grandeur il veut organiser ...
#
#                                               tokens  \
# 0  [olivia, personalisiertes, notizbuch, 150, sei...
# 1  [journal, des, arts, le, n, 133, du, 28, 09, 2...
# 2  [grand, stylet, ergonomique, bleu, gamepad, ni...
# 3  [peluche, donald, europe, disneyland, 2000, ma...
# 4                          [la, guerre, des, tuques]
#
#    designation_clean_length  description_clean_length  descr_dup_block  \
# 0                        11                         0            False
# 1                        38                         0            False
# 2                        11                       109            False
# 3                         8                         0            False
# 4                         4                        38            False
#
#    desig_dup_block                                  description_dedup  \
# 0            False
# 1            False
# 2            False  pilot style touch pen de marque speedlink est ...
# 3            False
# 4            False  luc a des id es de grandeur il veut organiser ...
#
#    description_dedup_length_chars  description_dedup_length_words  \
# 0                               0                               0
# 1                               0                               0
# 2                             663                             109
# 3                               0                               0
# 4                             180                              38
#
#    removed_chars  removed_words  description_dedup_length  \
# 0              0              0                         0
# 1              0              0                         0
# 2              0              0                       109
# 3              0              0                         0
# 4              0              0                        38
#
#                                description_clean_ini
# 0
# 1
# 2  pilot style touch pen de marque speedlink est ...
# 3
# 4  luc a des id es de grandeur il veut organiser ...

# %%
# tokenize
design_tokens = df["designation_clean"].str.split().explode()
descr_tokens = df["description_dedup"].str.split().explode()

# remove empty tokens if any
design_tokens = design_tokens.dropna()
descr_tokens = descr_tokens.dropna()

# detect numeric tokens
design_numeric = design_tokens.str.fullmatch(r"\d+")
descr_numeric = descr_tokens.str.fullmatch(r"\d+")

# counts
design_total = len(design_tokens)
descr_total = len(descr_tokens)

design_numeric_count = design_numeric.sum()
descr_numeric_count = descr_numeric.sum()

# percentages
design_numeric_pct = 100 * design_numeric_count / design_total
descr_numeric_pct = 100 * descr_numeric_count / descr_total

print("Designation numeric tokens:", design_numeric_count)
print("Designation total tokens:", design_total)
print("Designation percentage numeric:", round(design_numeric_pct,2), "%")

print()

print("Description numeric tokens:", descr_numeric_count)
print("Description total tokens:", descr_total)
print("Description percentage numeric:", round(descr_numeric_pct,2), "%")
# Out:
# Designation numeric tokens: 87939
# Designation total tokens: 979777
# Designation percentage numeric: 8.98 %
#
# Description numeric tokens: 555740
# Description total tokens: 6881112
# Description percentage numeric: 8.08 %

# %%
def top_word_in_caregory(df, columns, topN=5, top_categ=1, category=None):
    """
    Display side-by-side bar charts of the most frequent tokens for a selected
    product category, using one or more cleaned text columns.

    Parameters
    ----------
    df : pandas.DataFrame
        DataFrame containing at least:
        - 'prdtypecode'
        - the cleaned text columns '<column>_clean'

    columns : list of str
        List of original column names, without the suffix '_clean'.
        Example:
        ["designation", "description"]

    topN : int, default=5
        Number of most frequent tokens to display in each chart.

    top_categ : int, default=1
        Rank of the category by frequency.
        Used only if 'category' is not provided.
        Example:
        1 = most frequent category
        2 = second most frequent category

    category : int or None, default=None
        Specific prdtypecode to analyze.
        If provided, this overrides 'top_categ'.

    Behavior
    --------
    The function:
    1. Selects a category either by its rank in frequency or by an explicit code.
    2. Filters the dataframe to rows belonging to that category.
    3. Uses the corresponding cleaned columns '<column>_clean'.
    4. Tokenizes the text.
    5. Removes stopwords, short tokens (length <= 2), and purely numeric tokens.
    6. Computes the topN most frequent tokens.
    7. Displays one bar chart per column, side by side.

    Notes
    -----
    - Cleaned columns such as 'designation_clean' and 'description_clean'
      must already exist before using this function.
    - If a cleaned column is missing, a warning is displayed.
    - The variable 'stop_words' must already be defined.
    """

    category_counts = df["prdtypecode"].value_counts()

    if category is not None:
        chosen_category = category
    else:
        chosen_category = category_counts.index[top_categ - 1]

    if chosen_category not in category_counts.index:
        print(f"Warning: category {chosen_category} not found in 'prdtypecode'.")
        return

    cat_df = df[df["prdtypecode"] == chosen_category]

    print(f"Selected category: {chosen_category}")
    print(f"Number of samples: {category_counts[chosen_category]}")

    fig, axes = plt.subplots(1, len(columns), figsize=(6 * len(columns), 4))

    if len(columns) == 1:
        axes = [axes]

    for ax, col in zip(axes, columns):
        clean_col = col + "_clean"

        if clean_col not in df.columns:
            print(f"Warning: column '{clean_col}' not found. Prepare it beforehand.")
            ax.set_visible(False)
            continue

        words = cat_df[clean_col].str.split().explode()
        words = words[~words.isin(stop_words)]
        words = words[words.str.len() > 2]
        words = words[~words.str.isnumeric()]

        top_words = words.value_counts().head(topN)

        top_words.plot(kind="bar", ax=ax)

        ax.set_title(col, fontsize=16)
        ax.set_ylabel("frequency", fontsize=14)
        ax.set_xlabel("token", fontsize=14)
        
        ax.tick_params(axis="x", labelrotation=45, labelsize=12)
        ax.tick_params(axis="y", labelsize=12)

    plt.tight_layout()
    plt.show()



top_word_in_caregory(df, ["designation", "description"], topN=7)
top_word_in_caregory(df, ["designation", "description"], topN=7, top_categ=2)
top_word_in_caregory(df, ["designation", "description"], topN=7, category=1180)
# Out:
# Selected category: 2583
# Number of samples: 10209
# Selected category: 1560
# Number of samples: 5073
# Selected category: 1180
# Number of samples: 764
